# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# to know more about statistics refer book : complete business stat

# %%
data=sns.load_dataset('penguins')
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Data set : who will win the next elections
#
# * Which candidate will get maximum vote from party A?
# * How many candidates are there in both the parties?
#
# * According to you which party will win more seats?
#
# 1. Name
# 2. Age
# 3. Party
# 4. Caste
# 5. Education

# %% [markdown]
# Continuous data are always measurements and Discrete data will be a value

# %%
print('species-nominal',
      'island-nominal',
      'bill_length-continuous'
      )
# Out:
# species-nominal island-nominal bill_length-continuous

# %%
data1=sns.load_dataset('tips')
data1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
data['total_bill'].median()
# Out:
# 17.795

# %%
data['total_bill'].mode()
# Out:
# 0    13.42
# Name: total_bill, dtype: float64

# %%
q1=data['total_bill'].quantile(0.25)
q2=data['total_bill'].quantile(0.50)
q3=data['total_bill'].quantile(0.75)

q1
# Out:
# 13.3475

# %%
q2
# Out:
# 17.795

# %%
q3
# Out:
# 24.127499999999998

# %% [markdown]
# # 22/08/24

# %%
import sklearn.datasets

# %%
from sklearn.datasets import load_wine

# %%
targets=load_wine(as_frame=True)['target_names']

# %%
data=load_wine(as_frame=True).frame

# %% [markdown]
# # Descriptive Stats
#    If mean is higher than median then extreme values are on the right side

# %%
data['target']=data['target'].astype(object)

# %%
data.describe(include='all').fillna('-') #['target']
# Out:
#           alcohol malic_acid       ash alcalinity_of_ash  magnesium  \
# count       178.0      178.0     178.0             178.0      178.0
# unique          -          -         -                 -          -
# top             -          -         -                 -          -
# freq            -          -         -                 -          -
# mean    13.000618   2.336348  2.366517         19.494944  99.741573
# std      0.811827   1.117146  0.274344          3.339564  14.282484
# min         11.03       0.74      1.36              10.6       70.0
# 25%       12.3625     1.6025      2.21              17.2       88.0
# 50%         13.05      1.865      2.36              19.5       98.0
# 75%       13.6775     3.0825    2.5575              21.5      107.0
# max         14.83        5.8      3.23              30.0      162.0
#
#        total_phenols flavanoids nonflavanoid_phenols proanthocyanins  \
# count          178.0      178.0                178.0           178.0
# ...

# %%
data.skew()
# Out:
# alcohol                        -0.051482
# malic_acid                      1.039651
# ash                            -0.176699
# alcalinity_of_ash               0.213047
# magnesium                       1.098191
# total_phenols                   0.086639
# flavanoids                      0.025344
# nonflavanoid_phenols            0.450151
# proanthocyanins                 0.517137
# color_intensity                 0.868585
# hue                             0.021091
# od280/od315_of_diluted_wines   -0.307285
# proline                         0.767822
# target                          0.107431
# dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt
data.hist()
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.kurt()
# Out:
# alcohol                          -0.8525
# malic_acid                      0.299207
# ash                             1.143978
# alcalinity_of_ash               0.487942
# magnesium                       2.104991
# total_phenols                  -0.835627
# flavanoids                     -0.880382
# nonflavanoid_phenols           -0.637191
# proanthocyanins                 0.554649
# color_intensity                 0.381522
# hue                            -0.344096
# od280/od315_of_diluted_wines   -1.086435
# proline                        -0.248403
# target                         -1.322787
# dtype: object

# %%
import numpy as np
np.cbrt(data.malic_acid).skew()
# Out:
# 0.5463626933549727

# %%
from scipy import stats

# %%
data.malic_acid,_=stats.boxcox(data.malic_acid)
data.malic_acid.skew()
# Out:
# 0.0270553366313209

# %%
data2=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
data2.skew()
# Out:
# longitude            -0.304003
# latitude              0.471801
# housing_median_age    0.064894
# total_rooms           4.002730
# total_bedrooms        3.322637
# population            5.187212
# households            3.342668
# median_income         1.626693
# median_house_value    0.973037
# dtype: float64

# %%
data2.hist()
plt.tight_layout()
plt.show()

# %%
plt.hist(data2['longitude'])
print(data2['longitude'].skew())
plt.show()
# Out:
# -0.30400297675663496

# %%
data2.kurt()
# Out:
# longitude             -1.322330
# latitude              -1.112226
# housing_median_age    -0.800826
# total_rooms           29.515885
# total_bedrooms        19.692750
# population            80.861997
# households            20.692645
# median_income          4.764145
# median_house_value     0.303998
# dtype: float64

# %%
c=1
for column in data2.columns:
  t = data2[columns]
  skew=t.skew()
  plt.subplot(5,2,c)
  plt.hist(t,label=skew)
  c+=1

  plt.figure(figsize=(5,3))
  plt.legend()
  plt.suptitle("Skweness")
  plt.title(column)
  plt.tight_layout()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <ipython-input-75-abd28bd71ca0>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5,2,c)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
np.cbrt(data2.longitude).skew()
# Out:
# -0.2941567980207187

# %%
data2.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data3=data2.corr()
data3
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %%
sns.heatmap(data3,annot=True)
# Out:
# <Axes: >

# %%
X,Y=data2.drop('latitude',axis=1),data2.latitude

# %%
plt.axhline(0.10,color='green',label='strong')
plt.axhline(-0.10)
plt.axhline(-0.2,color='red',label='weak')
plt.axhline(0.2,color='orange',label='moderate')
plt.axhline(0.4,color='yellow',label='accurate')
plt.legend()
X.corrwith(Y).plot(kind='bar')
# Out:
# <Axes: >
